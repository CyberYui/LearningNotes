# %%
import requests
from bs4 import BeautifulSoup
import xlsxwriter

excelName = input('请输入excel名：')
titelName = input('请输入需要爬取的标题：')
workbook = xlsxwriter.Workbook(excelName+'.xlsx')
# 创建一个sheet
worksheet = workbook.add_worksheet()
href = []
text = []
for s in range(2,20):
    url = 'https://s.ixueshu.com/index.html?q='+titelName+'&page='+str(s)
    user_agent = {
        'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/77.0.3865.90 Safari/537.36'
    }
    res = requests.get(url)
    soup = BeautifulSoup(res.text, 'html.parser')
    items = soup.find_all('a',target='_blank')
    for i in range(1,len(items)-10,2):
        print(str(items[i].get("href"))+str(items[i].get_text()))
        href.append(items[i].get("href"))
        text.append(items[i].get_text())

worksheet.write(0, 0, "下载链接")
worksheet.write(0, 1, "论文标题标题")
for j in range(0,len(href)):
    worksheet.write(j+1, 0, href[j])
    worksheet.write(j+1, 1, text[j])
workbook.close()
# Out:
# 请输入excel名：pppt
# 请输入需要爬取的标题：internet
# https://www.ixueshu.com/document/8fa326a775a771d861163a8b69b2f5b7318947a18e7f9386.html广电运营商INTERNET多链路应用加速方案的研究
# https://www.ixueshu.com/document/ddd0971e43d1f84b68deee572d676001318947a18e7f9386.html一种基于Internet的在线网络安全比赛方法和系统
# https://www.ixueshu.com/document/e9d0c5b740fa83065dfeafdcb478b79c318947a18e7f9386.html信息技术-Internet实用教程教学设计的思考与实践
# https://www.ixueshu.com/document/e9d0c5b740fa83069dfa4ed627711ac7318947a18e7f9386.html基于Internet的中职计算机网络基础教学实践研究
# https://www.ixueshu.com/document/3310b82f4f180d58882147dad2baf9cc318947a18e7f9386.html基于Internet的竞争厂商产品选择与市场决策模型
# https://www.ixueshu.com/document/214c9856c461100740a37c7e2b492890318947a18e7f9386.html基于Internet的大型仪器预约系统的开发与应用
# https://www.ixueshu.com/document/b6a0a2e89f6b932212e732d1ccd8a93c318947a18e7f9386.htmlInternet下双渠道闭环供应链动态模型及其预测控制
# https://www.ixueshu.com/document/8fa326a775a771d813df8bdcb7fa79b9318947a18e7f9386.html基于Internet的智能自适应答疑系统的设计与实现
# https://www.ixueshu.com/document/889d1a6efed6edd8d130a84bb971a0d3318947a18e7f9386.html基于internet视角的区域物流信息资源共享模式构建
# https://www.ixueshu.com/document/466acba9d1aca3e9425028cab5c41970318947a18e7f9386.htmlInternet中的自适应神经网络终端滑模拥塞控制算法
# https://www.ixueshu.com/document/b6a0a2e89f6b9322d356329f716a1f2a318947a18e7f9386.html基于Internet的轨道车远程监控管理系统的设计与实现
# https://www.ixueshu.com/document/79edc05c2a32f398fbc80167dca8fc52318947a18e7f9386.html基于Internet和Web技术的远程监控系统研究与实现
# https://www.ixueshu.com/document/79da8b70f0a1bdba62c22cc891557659318947a18e7f9386.htmlInternet路由宣告的可信度测量与分析
# https://www.ixueshu.com/document/586c8b8cb957527f47120feed1d51a18318947a18e7f9386.html浅论Internet背景下教师对大学英语教学的管理
# https://www.ixueshu.com/document/79da8b70f0a1bdba42bd987cee32cd93318947a18e7f9386.html支持Internet互联的AODV路由协议实现与优化
# https://www.ixueshu.com/document/f21b7d05519c59113a324a5996c5275b318947a18e7f9386.html国际货运代理服务基于INTERNET的在线实训探析
# https://www.ixueshu.com/document/79edc05c2a32f3989cb547a9bf5078c1318947a18e7f9386.html基于Internet和Cortex-M3的音视频切换器的研究与设计
# https://www.ixueshu.com/document/674fa6ad8a98c60070b44d621c88d858318947a18e7f9386.html当前基于Internet的产品设计与制造及其关键技术探究
# https://www.ixueshu.com/document/83b73e57dd554a55a80fa72dc26d04e1318947a18e7f9386.html一种改善Internet扩展性的域间路由寻址结构
# https://www.ixueshu.com/document/aa821c577793404ba2935681b89f1b66318947a18e7f9386.html一种改善Internet扩展性的域问路由寻址结构
# https://www.ixueshu.com/document/0c25ea62490640e5ae61688856fdfa16318947a18e7f9386.html一种连接WSN与Internet的多核嵌入式网关设计与实现
# https://www.ixueshu.com/document/197c7d82853bd0e7e5c059b6989d1340318947a18e7f9386.htmlInternet环境下遥操作机器人系统传输时延的研究综述
# https://www.ixueshu.com/document/10a911bfed7419cea0aa5514161db40e318947a18e7f9386.html基于Internet的汽车电子远程诊断技术的分析
# https://www.ixueshu.com/document/3750cf6b88dc8b1263b35820496e18d8318947a18e7f9386.html基于Internet的虚拟外贸模拟实训系统的研究与开发
# https://www.ixueshu.com/document/3750cf6b88dc8b12c37643555082d7d5318947a18e7f9386.html泛在短距离无线网络接入Internet的研究与探讨
# https://www.ixueshu.com/document/3750cf6b88dc8b12685f17bef7c788ab318947a18e7f9386.html路由器级Internet网络静态鲁棒性研究及其优化
# https://www.ixueshu.com/document/e9d0c5b740fa830684a36cc0b56eee55318947a18e7f9386.html基于Internet的新疆农业科学院南繁种质资源数据库构建
# https://www.ixueshu.com/document/57827a485ac3460c1ca2f3ca7eed7fda318947a18e7f9386.html一种基于Internet电子商务的积分分销方法
# https://www.ixueshu.com/document/07ab6bb454441f20a53d0b93e8ecdd2c318947a18e7f9386.html基于Internet与数据库技术的自动化立体分拣系统
# https://www.ixueshu.com/document/214c9856c46110076b8fba37ccd88d76318947a18e7f9386.html基于目标导向的Internet与网页设计课程教学改革研究
# https://www.ixueshu.com/document/6a3261ae85e489b855cf5c670c0d2000318947a18e7f9386.html基于Internet+的创新创业理论与实践路径研究
# https://www.ixueshu.com/document/214c9856c46110071564044db3b5b897318947a18e7f9386.html基于ARM的嵌入式Internet远程控制系统的研究与实现
# https://www.ixueshu.com/document/889d1a6efed6edd88fb362a7beb25ce7318947a18e7f9386.html基于ZigBee和Internet的无线智能家居网关系统
# https://www.ixueshu.com/document/2824c82399116b764abb79834011e1b5318947a18e7f9386.html利用流量负载均衡与带宽控制优化企业Internet网络
# https://www.ixueshu.com/document/79da8b70f0a1bdbaec4207df35a85dc6318947a18e7f9386.html基于Internet呼叫中心的气调库控制系统设计与实现
# https://www.ixueshu.com/document/16c147a8ae4f40387618eeac01836af2318947a18e7f9386.html基于ZigBee和Internet的无线智能家居网关系统
# https://www.ixueshu.com/document/4e0dce557d53fd6c6f0a086160391fd8318947a18e7f9386.html基于ZigBee和Internet的无线智能家居网关系统
# https://www.ixueshu.com/document/2748d45327f762dbe9200653170ab5cb318947a18e7f9386.htmlInternet环境下的体育院校学生学籍信息管理系统的设计
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-16d7ab6bf121> in <module>
#      15     url = 'https://s.ixueshu.com/index.html?q='+titelName+'&page='+str(s)
#      16     user_agent = {
# ---> 17         'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/77.0.3865.90 Safari/537.36'
#      18     }
#      19     res = requests.get(url)
#
# ~\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# ~\Anaconda3\lib\http\client.py in getresponse(self)
#    1319         try:
#    1320             try:
# -> 1321                 response.begin()
#    1322             except ConnectionError:
#    1323                 self.close()
#
# ~\Anaconda3\lib\http\client.py in begin(self)
#     294         # read until we get a non-100 response
#     295         while True:
# --> 296             version, status, reason = self._read_status()
#     297             if status != CONTINUE:
#     298                 break
#
# ~\Anaconda3\lib\http\client.py in _read_status(self)
#     255
#     256     def _read_status(self):
# --> 257         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     258         if len(line) > _MAXLINE:
#     259             raise LineTooLong("status line")
#
# ~\Anaconda3\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     295     def recv_into(self, *args, **kwargs):
#     296         try:
# --> 297             return self.connection.recv_into(*args, **kwargs)
#     298         except OpenSSL.SSL.SysCallError as e:
#     299             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# ~\Anaconda3\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1819             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1820         else:
# -> 1821             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1822         self._raise_ssl_error(self._ssl, result)
#    1823
#
# KeyboardInterrupt:
