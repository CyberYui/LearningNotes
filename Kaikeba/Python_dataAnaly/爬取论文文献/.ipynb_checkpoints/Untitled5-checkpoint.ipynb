# %%
import requests
from bs4 import BeautifulSoup
import xlsxwriter

excelName = input('请输入excel名：')
titelName = input('请输入需要爬取的标题：')
workbook = xlsxwriter.Workbook(excelName+'.xlsx')
# 创建一个sheet
worksheet = workbook.add_worksheet()
href = []
text = []
for s in range(2,20):
    url = 'https://s.ixueshu.com/index.html?q='+titelName+'&page='+str(s)
    user_agent = {
        'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/77.0.3865.90 Safari/537.36'
    }
    res = requests.get(url)
    soup = BeautifulSoup(res.text, 'html.parser')
    items = soup.find_all('a',target='_blank')
    for i in range(1,len(items)-10,2):
        print(str(items[i].get("href"))+str(items[i].get_text()))
        href.append(items[i].get("href"))
        text.append(items[i].get_text())

worksheet.write(0, 0, "下载链接")
worksheet.write(0, 1, "论文标题标题")
for j in range(0,len(href)):
    worksheet.write(j+1, 0, href[j])
    worksheet.write(j+1, 1, text[j])
workbook.close()
# Out:
# 请输入excel名：python1
# 请输入需要爬取的标题：Python
# https://www.ixueshu.com/document/6a3261ae85e489b84f8e5d65526be1af318947a18e7f9386.html基于Python的新浪新闻爬虫系统的设计与实现
# https://www.ixueshu.com/document/e4859208ffe87b81f6eb4260c310e025318947a18e7f9386.html基于Python的可视化数据分析平台设计与实现
# https://www.ixueshu.com/document/a1a89c49bc6bff80785b1e4bc250b467318947a18e7f9386.htmlPython在FY-2G定量业务产品自动可视化中的应用
# https://www.ixueshu.com/document/b6a0a2e89f6b9322b787dba142cdb2e5318947a18e7f9386.html利用python语言对室内热舒适环境进行数据分析
# https://www.ixueshu.com/document/e4859208ffe87b814ca5dd44403799f4318947a18e7f9386.html大数据时代下基于Python的网络信息爬取技术
# https://www.ixueshu.com/document/e4859208ffe87b81c23ada6714ba580f318947a18e7f9386.html基于Python的网络传输文件功能的设计与实现
# https://www.ixueshu.com/document/a1a89c49bc6bff80239782801bd17e3a318947a18e7f9386.html基于Python的网络传输文件功能的设计与实现
# https://www.ixueshu.com/document/e4859208ffe87b81d14f7a94c2d28b19318947a18e7f9386.html基于Python的三维建模可视化系统研究
# https://www.ixueshu.com/document/6a3261ae85e489b8819374c4b6ca6322318947a18e7f9386.html基于Python的单层感知器分类算法的实现
# https://www.ixueshu.com/document/2bf4da80914dcf5ce3ee8ed5bea6da15318947a18e7f9386.html基于Python的户外通讯设备连接关系的挖掘研究
# https://www.ixueshu.com/document/68abee163511291e2464fd65f1793bf8318947a18e7f9386.html基于Python语言雷达信号覆盖软件的设计与实现
# https://www.ixueshu.com/document/035f7dd25a73b9117ef7fec4dd86f897318947a18e7f9386.html基于python程序设计的发动机舱盖多学科联合优化
# https://www.ixueshu.com/document/b6a0a2e89f6b9322200671e612e683d1318947a18e7f9386.html一种基于Python的二维码传输系统的设计与实现
# https://www.ixueshu.com/document/99b122264be0bceeca547cb8520d2b68318947a18e7f9386.html基于Arduino与Python的实验室联动门禁报警系统设计
# https://www.ixueshu.com/document/b6a0a2e89f6b93228f73eef8fbb13a1a318947a18e7f9386.html基于Python的分布式网络爬虫系统的设计与实现
# https://www.ixueshu.com/document/18debfaea2340c5d7dbd635d9f3b17a7318947a18e7f9386.html基于Python的可配置自动化爬虫系统的设计与实现
# https://www.ixueshu.com/document/22cde1e97521595b9fa45ddc0f63821a318947a18e7f9386.html个体差异对Python爬虫获取教育大数据的影响研究
# https://www.ixueshu.com/document/e4859208ffe87b8138dc4fb10e317ca0318947a18e7f9386.html基于Python爬虫技术的网页数据抓取与分析研究
# https://www.ixueshu.com/document/6a3261ae85e489b8f02f66a2980ee650318947a18e7f9386.html基于Python的关联规则算法在推荐领域的应用研究
# https://www.ixueshu.com/document/b6a0a2e89f6b9322e94bed8f7f1586af318947a18e7f9386.html基于Python的豆瓣图书评论数据获取与可视化分析
# https://www.ixueshu.com/document/68abee163511291e6aa4e51013a3868b318947a18e7f9386.html基于python的某型航发高涡平衡单面配平数据处理
# https://www.ixueshu.com/document/68abee163511291e475dea0b3374dff1318947a18e7f9386.html基于Python的关联规则算法在推荐领域的应用研究
# https://www.ixueshu.com/document/03d3884ec484856c74bf913d996f9ecd318947a18e7f9386.html基于Python的招聘网站信息爬取与数据分析
# https://www.ixueshu.com/document/b6a0a2e89f6b9322a01a664f4c91c3f1318947a18e7f9386.html基于Python的彩色图像忆阻系统多稳态加密
# https://www.ixueshu.com/document/6a3261ae85e489b8e02557211d0cda09318947a18e7f9386.html基于Python的多线程网络爬虫的设计与实现
# https://www.ixueshu.com/document/07ab6bb454441f20b650fd3e41baea6d318947a18e7f9386.html基于Python的网络协议分析工具的研究与应用
# https://www.ixueshu.com/document/10a911bfed7419ce9fb3a4a3cbc7df09318947a18e7f9386.html面向Python程序的静态死锁检测方法的研究
# https://www.ixueshu.com/document/de08af20441fee03bfab361085ea5eab318947a18e7f9386.html基于Python编程的星管组合装药结构完整性分析
# https://www.ixueshu.com/document/b6a0a2e89f6b9322daf33d81a3c4efb8318947a18e7f9386.html基于Acrgis的Python脚本在森林资源年度更新中的应用
# https://www.ixueshu.com/document/b6a0a2e89f6b9322b2ceefc65d714261318947a18e7f9386.html基于python的处理CSV文件和JSON数据的程序与设计
# https://www.ixueshu.com/document/03d3884ec484856c1f28adcef73bf9f1318947a18e7f9386.html基于Python的圆锥滚子轴承滚子修形软件开发
# https://www.ixueshu.com/document/a8b9855222fc772cc6b67c9072e192fa318947a18e7f9386.html一种基于python的大数据分布式任务处理装置
# https://www.ixueshu.com/document/22cde1e97521595b27e2e0697ef15153318947a18e7f9386.html基于Python的ABAQUS二次开发在骨钻削仿真中的应用
# https://www.ixueshu.com/document/be6c862ae782c141a561ac631abcaa1b318947a18e7f9386.htmlMICAPS第四类数据格式Python处理库的实现和应用
# https://www.ixueshu.com/document/16c147a8ae4f4038b22eccf2114e3ab1318947a18e7f9386.html用ArcGIS的Python脚本计算采煤沉陷区土地损毁程度
# https://www.ixueshu.com/document/a1a89c49bc6bff8025c6cad6095a5d55318947a18e7f9386.html基于Hadoop和Python的多角度电影数据可视化分析
# https://www.ixueshu.com/document/57827a485ac3460c27c64fe0a2abb5a4318947a18e7f9386.html一种基于Python多进程库创建systemd服务的方法
# https://www.ixueshu.com/document/79da8b70f0a1bdbae0506b63a5bedd6f318947a18e7f9386.html基于Python的自动化测试脚本管理平台的设计与实现
# https://www.ixueshu.com/document/6a3261ae85e489b87b34d126d0d1b8bd318947a18e7f9386.html基于Hadoop和Python的多角度电影数据可视化分析
# https://www.ixueshu.com/document/a8b9855222fc772c211834673f62751f318947a18e7f9386.html一种基于python的云服务节点自动测试方法及装置
# https://www.ixueshu.com/document/10a911bfed7419ce6d4d6c0e7d8721bf318947a18e7f9386.htmlPython与Spark集群在收费数据分析中的应用
# https://www.ixueshu.com/document/b6a0a2e89f6b9322167146ea3ce521c1318947a18e7f9386.html基于Python的网络语料获取和文本提取方法探索
# https://www.ixueshu.com/document/79edc05c2a32f398589b8b75f3863029318947a18e7f9386.html基于Python的嵌入式开发工具的设计与实现
# https://www.ixueshu.com/document/a8b9855222fc772c2bd44d4959467821318947a18e7f9386.html一种基于树莓派和Python语言的频率合成器系统
# https://www.ixueshu.com/document/a8b9855222fc772c5bdc7dfe8eecabdb318947a18e7f9386.html一种基于python的轻量化网络设备端口探测方法
# https://www.ixueshu.com/document/b6a0a2e89f6b9322397f1ad44f70639c318947a18e7f9386.html基于Python爬虫原理的篮球鞋选择程序的设计与实现
# https://www.ixueshu.com/document/6a3261ae85e489b8d15b5abd2acfbdb4318947a18e7f9386.htmlMICAPS第四类数据格式Python处理库的实现和应用
# https://www.ixueshu.com/document/68abee163511291eb5ff0acb73637052318947a18e7f9386.html图书借阅推荐系统中python与数据库连接的具体实现
# https://www.ixueshu.com/document/b6a0a2e89f6b932245372e3fc9b74975318947a18e7f9386.html利用Python研究缓凝剂对磷建筑石膏性能的影响
# https://www.ixueshu.com/document/e9d0c5b740fa8306f4cce0195417d24c318947a18e7f9386.html基于Java与Python的面向对象编程的基本特征研究
# https://www.ixueshu.com/document/22cde1e97521595b69737d960820e793318947a18e7f9386.html一种基于Python的商品评论数据智能获取与分析技术
# https://www.ixueshu.com/document/1662074a158b7fce087c925a93c03468318947a18e7f9386.html基于Python的网络关键字热度获取工具的研究与实现
# https://www.ixueshu.com/document/e9d0c5b740fa8306d2739627b2e7cda7318947a18e7f9386.html基于Python正则表达式的航空气象观测报文检测
# https://www.ixueshu.com/document/03d3884ec484856c1d154944879148b3318947a18e7f9386.html论高中新课标下Python课程对学生计算思维的培养
# https://www.ixueshu.com/document/99b122264be0bcee28237ff01881e987318947a18e7f9386.html基于Python语言和支持向量机的字符验证码识别
# https://www.ixueshu.com/document/e4859208ffe87b81565012ad6eb50a3d318947a18e7f9386.html基于python的网络及信息系统安全过程管理工具
# https://www.ixueshu.com/document/035f7dd25a73b911ad5598ff83c0a14f318947a18e7f9386.html面向Python语言的社区发现软件开发工具包的设计
# https://www.ixueshu.com/document/18debfaea2340c5d1be6f3e3a9e46f4b318947a18e7f9386.htmlPython框架下基于主题的数据爬取技术研究与实现
# https://www.ixueshu.com/document/03d3884ec484856c3946b6c85e5684f7318947a18e7f9386.html基于Python语言的学生考勤管理系统的设计与实现
# https://www.ixueshu.com/document/03d3884ec484856cb421f697c0ced1a7318947a18e7f9386.html基于Python的藏文不自由虚词校对算法研究与实现
# https://www.ixueshu.com/document/d8b32bd93ad3e55c0f2877f4255181d6318947a18e7f9386.html一种基于代码对象的Python钩子函数方法和装置
# https://www.ixueshu.com/document/03d3884ec484856c3946b6c85e5684f7318947a18e7f9386.html基于Python语言的学生考勤管理系统的设计与实现
# https://www.ixueshu.com/document/be6c862ae782c141503e25dc75a46539318947a18e7f9386.html基于Python语言的RFID校园卡的充值功能设计与实现
# https://www.ixueshu.com/document/6a3261ae85e489b80881de5690f1d596318947a18e7f9386.html基于Python的关联规则算法在推荐领域的应用研究
# https://www.ixueshu.com/document/10a911bfed7419cefae2e1447f0b7e23318947a18e7f9386.html基于Python语言的RFID校园卡的充值功能设计与实现
# https://www.ixueshu.com/document/be6c862ae782c1416f91356508d33b23318947a18e7f9386.html用Python数据分析方法进行汉字声调频率统计分析
# https://www.ixueshu.com/document/85c32d43d1e3f49dceb1427a252f1a7f318947a18e7f9386.html基于Python扩展模块的多进程共享系统及方法
# https://www.ixueshu.com/document/1662074a158b7fcec5931f78745b5cd3318947a18e7f9386.html一种基于Python和BP神经网络的股票预测方法
# https://www.ixueshu.com/document/03d3884ec484856cc29f7c9c9c589064318947a18e7f9386.htmlPython第三方库在Excel文件读写中的应用
# https://www.ixueshu.com/document/03d3884ec484856c3355d16e912eda3d318947a18e7f9386.html基于python的1∶1万地图快速栅格化纠正方法
# https://www.ixueshu.com/document/18debfaea2340c5d03483391aec98b19318947a18e7f9386.htmlPython脚本在地理国情监测数据预处理中的应用
# https://www.ixueshu.com/document/b6a0a2e89f6b93220ec476904528cd54318947a18e7f9386.htmlPython脚本在地理国情监测数据预处理中的应用
# https://www.ixueshu.com/document/af5a20653d8fe20ff481e3a214ce861b318947a18e7f9386.html基于PYTHON及ARCPY的多进程空间数据检查任务实现
# https://www.ixueshu.com/document/22cde1e97521595b9529630cabf18e5d318947a18e7f9386.htmlPython可视化技术在BP神经网络教学中的应用
# https://www.ixueshu.com/document/4eb5d095a73dae368604fe0898e2025d318947a18e7f9386.html一种基于Python自动化测试的方法、系统及测试终端
# https://www.ixueshu.com/document/3a073adb15ec6629915555c07ba44494318947a18e7f9386.html基于Python的梁柱式木结构框架抗火数值模拟系统
# https://www.ixueshu.com/document/e9d0c5b740fa83068de26541c73b9610318947a18e7f9386.html基于VB与Python的地理国情要素及地表覆盖统计实现
# https://www.ixueshu.com/document/de08af20441fee03591ed3ae84a2b7ef318947a18e7f9386.html基于Python语言的马尔科夫链模型的算法设计与实现
# https://www.ixueshu.com/document/b6a0a2e89f6b9322177c483f223f2bec318947a18e7f9386.html以爬虫为兴趣牵引的Python教学方案探索与实践
# https://www.ixueshu.com/document/18debfaea2340c5d74f074819580765c318947a18e7f9386.html面向文科专业开设Python程序设计课程的可行性分析
# https://www.ixueshu.com/document/99b122264be0bceeab98db653c2281d8318947a18e7f9386.htmlPYTHON在企业信息自动化运维工作中的应用
# https://www.ixueshu.com/document/03d3884ec484856c15a8f41852eb1320318947a18e7f9386.html基于Python的非接触式人体测量数据可用性验证分析
# https://www.ixueshu.com/document/7cf4273122025963edaf6da9eb7e2430318947a18e7f9386.html巧用Python保存填图资料和显示欧洲中心产品
# https://www.ixueshu.com/document/a8b9855222fc772cd291c009193aba35318947a18e7f9386.html一种基于python的虚拟化系统自动化测试系统及方法
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-16d7ab6bf121> in <module>
#      15     url = 'https://s.ixueshu.com/index.html?q='+titelName+'&page='+str(s)
#      16     user_agent = {
# ---> 17         'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/77.0.3865.90 Safari/537.36'
#      18     }
#      19     res = requests.get(url)
#
# ~\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# ~\Anaconda3\lib\http\client.py in getresponse(self)
#    1319         try:
#    1320             try:
# -> 1321                 response.begin()
#    1322             except ConnectionError:
#    1323                 self.close()
#
# ~\Anaconda3\lib\http\client.py in begin(self)
#     294         # read until we get a non-100 response
#     295         while True:
# --> 296             version, status, reason = self._read_status()
#     297             if status != CONTINUE:
#     298                 break
#
# ~\Anaconda3\lib\http\client.py in _read_status(self)
#     255
#     256     def _read_status(self):
# --> 257         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     258         if len(line) > _MAXLINE:
#     259             raise LineTooLong("status line")
#
# ~\Anaconda3\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     295     def recv_into(self, *args, **kwargs):
#     296         try:
# --> 297             return self.connection.recv_into(*args, **kwargs)
#     298         except OpenSSL.SSL.SysCallError as e:
#     299             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# ~\Anaconda3\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1819             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1820         else:
# -> 1821             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1822         self._raise_ssl_error(self._ssl, result)
#    1823
#
# KeyboardInterrupt:
